# %% [markdown]
# # Deliverable 3 - Captioning

# %% [markdown]
# ## Import

# %%
# Disable Tensorflow's warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# your model focuses on during captioning
import matplotlib.pyplot as plt

import collections
import random
import numpy as np
import os
import time
import json
from PIL import Image
import pickle
# Out:
# 2022-10-20 09:47:30.032936: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Load COCO Dataset

# %%
annotation_file = 'data/3_annotations/captions_train2014.json'
image_folder = 'data/3_train2014/'

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/kally/Documents/workspace/IA/IA-A5-Tensorflow/3_captioning.ipynb Cellule 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/kally/Documents/workspace/IA/IA-A5-Tensorflow/3_captioning.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> with open(annotation_file, 'r') as f:
#       <a href='vscode-notebook-cell:/home/kally/Documents/workspace/IA/IA-A5-Tensorflow/3_captioning.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     annotations = json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/3_annotations/captions_train2014.json'

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
  caption = f"<start> {val['caption']} <end>"
  image_path = image_folder + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
  image_path_to_caption[image_path].append(caption)

image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# %%
# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will
# lead to 30,000 examples.
# train_image_paths = image_paths[:6000]
train_image_paths = image_paths[:10]

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
  caption_list = image_path_to_caption[image_path]
  train_captions.extend(caption_list)
  img_name_vector.extend([image_path] * len(caption_list))

print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> A laptop computer sitting on top of a desk. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %% [markdown]
# ## Load InceptionV3 model

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %% [markdown]
# ## Preprocessing Images with InceptionV3

# %% [markdown]
# Convert images at format expected by InceptionV3:
# * Resize the image to 299px by 299px
# * Normalize the image so that it contains pixels between -1 and 1

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.keras.layers.Resizing(299, 299)(img)
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %% [markdown]
# Preprocess each image with InceptionV3 and cache it

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

for img, path in image_dataset:
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())

# %% [markdown]
# ## Preprocessing and tokenize subtitles

# %%
caption_dataset = tf.data.Dataset.from_tensor_slices(train_captions)

# We will override the default standardization of TextVectorization to preserve
# "<>" characters, so we preserve the tokens for the <start> and <end>.
def standardize(inputs):
  inputs = tf.strings.lower(inputs)
  return tf.strings.regex_replace(inputs,
                                  r"!\"#$%&\(\)\*\+.,-/:;=?@\[\\\]^_`{|}~", "")

# Max word count for a caption.
max_length = 50
# Use the top 5000 words for a vocabulary.
vocabulary_size = 5000
tokenizer = tf.keras.layers.TextVectorization(
    max_tokens=vocabulary_size,
    standardize=standardize,
    output_sequence_length=max_length)
# Learn the vocabulary from the caption data.
tokenizer.adapt(caption_dataset)

# Create the tokenized vectors
cap_vector = caption_dataset.map(lambda x: tokenizer(x))

# Create mappings for words to indices and indicies to words.
word_to_index = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary())
index_to_word = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary(),
    invert=True)

# %%
with open('word_to_index', 'wb') as outp:  # Overwrites any existing file.
      pickle.dump(word_to_index, outp, pickle.HIGHEST_PROTOCOL)
with open('index_to_word', 'wb') as outp:  # Overwrites any existing file.
      pickle.dump(index_to_word, outp, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Create training and validation sets

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

# %% [markdown]
# ## Create Dataset and Batches

# %%
# Feel free to change these parameters according to your system's configuration

BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from InceptionV3 is (64, 2048)
# These two variables represent that vector shape
features_shape = 2048
attention_features_shape = 64

# %%
# Load the numpy files
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int64]),
          num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## Model

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, features, hidden):
    # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

    # hidden shape == (batch_size, hidden_size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
    hidden_with_time_axis = tf.expand_dims(hidden, 1)

    # attention_hidden_layer shape == (batch_size, 64, units)
    attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                         self.W2(hidden_with_time_axis)))

    # score shape == (batch_size, 64, 1)
    # This gives you an unnormalized score for each image feature.
    score = self.V(attention_hidden_layer)

    # attention_weights shape == (batch_size, 64, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.embedding_dim = embedding_dim
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x
    
    def get_config(self):
      return {"embedding_dim": self.embedding_dim}

    @classmethod
    def from_config(cls, config):
      return cls(**config)

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units

    self.embedding_dim = embedding_dim
    self.vocab_size = vocab_size
    self.embedding = tf.keras.layers.Embedding(self.vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(self.vocab_size)

    self.attention = BahdanauAttention(self.units)

  def call(self, x, features, hidden):
    # defining attention as a separate model
    context_vector, attention_weights = self.attention(features, hidden)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # shape == (batch_size, max_length, hidden_size)
    x = self.fc1(output)

    # x shape == (batch_size * max_length, hidden_size)
    x = tf.reshape(x, (-1, x.shape[2]))

    # output shape == (batch_size * max_length, vocab)
    x = self.fc2(x)

    return x, state, attention_weights

  def _reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

  def get_config(self):
    return {"embedding_dim": self.embedding_dim,"units": self.units,"embedding_dim": self.embedding_dim}

  @classmethod
  def from_config(cls, config):
      return cls(**config)

  @tf.function
  def reset_state(self, batch_size):
      """ tf.function-deocrated version of _reset_state """
      return self._reset_state(batch_size)

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, tokenizer.vocabulary_size())

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoint

# %%
checkpoint_path = "./checkpoints/3_captioning_train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %% [markdown]
# ## Train

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0

  # initializing the hidden state for each batch
  # because the captions are not related from image to image
  hidden = decoder.reset_state(batch_size=target.shape[0])

  dec_input = tf.expand_dims([word_to_index('<start>')] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          # passing the features through the decoder
          predictions, hidden, _ = decoder(dec_input, features, hidden)

          loss += loss_function(target[:, i], predictions)

          # using teacher forcing
          dec_input = tf.expand_dims(target[:, i], 1)

  total_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, trainable_variables)

  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, total_loss

# %%
EPOCHS = 1

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            average_batch_loss = batch_loss.numpy()/int(target.shape[1])
            print(f'Epoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
      ckpt_manager.save()

    print(f'Epoch {epoch+1} Loss {total_loss/num_steps:.6f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 5 Batch 0 Loss 2.2018
# Epoch 5 Batch 100 Loss 0.9332
# Epoch 5 Batch 200 Loss 0.9574
# Epoch 5 Batch 300 Loss 0.8123
# Epoch 5 Batch 400 Loss 0.8645
# Epoch 5 Batch 500 Loss 0.7572
# Epoch 5 Batch 600 Loss 0.6930
# Epoch 5 Batch 700 Loss 0.7590
# Epoch 5 Batch 800 Loss 0.6568
# Epoch 5 Batch 900 Loss 0.7110
# Epoch 5 Batch 1000 Loss 0.7354
# Epoch 5 Batch 1100 Loss 0.7172
# Epoch 5 Batch 1200 Loss 0.7115
# Epoch 5 Batch 1300 Loss 0.6733
# Epoch 5 Batch 1400 Loss 0.7023
# Epoch 5 Batch 1500 Loss 0.6625
# Epoch 5 Batch 1600 Loss 0.7058
# Epoch 5 Batch 1700 Loss 0.7119
# Epoch 5 Batch 1800 Loss 0.6946
# Epoch 5 Batch 1900 Loss 0.6345
# Epoch 5 Batch 2000 Loss 0.7132
# Epoch 5 Batch 2100 Loss 0.6556
# Epoch 5 Batch 2200 Loss 0.7079
# Epoch 5 Batch 2300 Loss 0.6943
# Epoch 5 Batch 2400 Loss 0.6621
# Epoch 5 Batch 2500 Loss 0.7236
# Epoch 5 Batch 2600 Loss 0.6615
# Epoch 5 Batch 2700 Loss 0.7176
# Epoch 5 Batch 2800 Loss 0.6378
# Epoch 5 Batch 2900 Loss 0.6734
# Epoch 5 Batch 3000 Loss 0.6515
# Epoch 5 Batch 3100 Loss 0.6221
# Epoch 5 Batch 3200 Loss 0.6398
# Epoch 5 Batch 3300 Loss 0.6325
# Epoch 5 Batch 3400 Loss 0.6840
# Epoch 5 Batch 3500 Loss 0.6857
# Epoch 5 Batch 3600 Loss 0.7223
# Epoch 5 Batch 3700 Loss 0.6437
# Epoch 5 Batch 3800 Loss 0.6600
# Epoch 5 Batch 3900 Loss 0.6371
# Epoch 5 Batch 4000 Loss 0.6286
# Epoch 5 Batch 4100 Loss 0.6472
# Epoch 5 Batch 4200 Loss 0.7210
# Epoch 5 Batch 4300 Loss 0.6404
# Epoch 5 Batch 4400 Loss 0.6548
# Epoch 5 Batch 4500 Loss 0.5983
# Epoch 5 Batch 4600 Loss 0.5913
# Epoch 5 Batch 4700 Loss 0.6266
# Epoch 5 Batch 4800 Loss 0.6612
# Epoch 5 Batch 4900 Loss 0.6500
# Epoch 5 Batch 5000 Loss 0.6246
# Epoch 5 Batch 5100 Loss 0.7046
# Epoch 5 Loss 0.699506
# Time taken for 1 epoch 1160.61 sec
#
# Epoch 6 Batch 0 Loss 0.6971
# Epoch 6 Batch 100 Loss 0.6300
# Epoch 6 Batch 200 Loss 0.5973
# Epoch 6 Batch 300 Loss 0.5801
# Epoch 6 Batch 400 Loss 0.5920
# Epoch 6 Batch 500 Loss 0.6059
# Epoch 6 Batch 600 Loss 0.6083
# Epoch 6 Batch 700 Loss 0.6101
# Epoch 6 Batch 800 Loss 0.6547
# Epoch 6 Batch 900 Loss 0.7069
# Epoch 6 Batch 1000 Loss 0.6100
# Epoch 6 Batch 1100 Loss 0.6303
# Epoch 6 Batch 1200 Loss 0.6058
# Epoch 6 Batch 1300 Loss 0.5899
# Epoch 6 Batch 1400 Loss 0.6390
# Epoch 6 Batch 1500 Loss 0.6058
# Epoch 6 Batch 1600 Loss 0.6370
# Epoch 6 Batch 1700 Loss 0.5767
# Epoch 6 Batch 1800 Loss 0.6129
# Epoch 6 Batch 1900 Loss 0.6181
# Epoch 6 Batch 2000 Loss 0.5954
# Epoch 6 Batch 2100 Loss 0.5963
# Epoch 6 Batch 2200 Loss 0.5773
# Epoch 6 Batch 2300 Loss 0.6411
# Epoch 6 Batch 2400 Loss 0.5947
# Epoch 6 Batch 2500 Loss 0.5715
# Epoch 6 Batch 2600 Loss 0.6013
# Epoch 6 Batch 2700 Loss 0.6081
# Epoch 6 Batch 2800 Loss 0.6166
# Epoch 6 Batch 2900 Loss 0.5813
# Epoch 6 Batch 3000 Loss 0.6080
# Epoch 6 Batch 3100 Loss 0.5738
# Epoch 6 Batch 3200 Loss 0.6079
# Epoch 6 Batch 3300 Loss 0.5646
# Epoch 6 Batch 3400 Loss 0.6481
# Epoch 6 Batch 3500 Loss 0.6103
# Epoch 6 Batch 3600 Loss 0.6477
# Epoch 6 Batch 3700 Loss 0.6524
# Epoch 6 Batch 3800 Loss 0.5689
# Epoch 6 Batch 3900 Loss 0.6319
# Epoch 6 Batch 4000 Loss 0.6047
# Epoch 6 Batch 4100 Loss 0.5680
# Epoch 6 Batch 4200 Loss 0.6030
# Epoch 6 Batch 4300 Loss 0.5866
# Epoch 6 Batch 4400 Loss 0.6126
# Epoch 6 Batch 4500 Loss 0.6417
# Epoch 6 Batch 4600 Loss 0.6021
# Epoch 6 Batch 4700 Loss 0.6042
# Epoch 6 Batch 4800 Loss 0.6136
# Epoch 6 Batch 4900 Loss 0.5988
# Epoch 6 Batch 5000 Loss 0.5822
# Epoch 6 Batch 5100 Loss 0.6409
# Epoch 6 Loss 0.616026
# Time taken for 1 epoch 1089.26 sec
#
# Epoch 7 Batch 0 Loss 0.6343
# Epoch 7 Batch 100 Loss 0.5583
# Epoch 7 Batch 200 Loss 0.6181
# Epoch 7 Batch 300 Loss 0.6018
# Epoch 7 Batch 400 Loss 0.6266
# Epoch 7 Batch 500 Loss 0.5975
# Epoch 7 Batch 600 Loss 0.5798
# Epoch 7 Batch 700 Loss 0.5879
# Epoch 7 Batch 800 Loss 0.5768
# Epoch 7 Batch 900 Loss 0.5823
# Epoch 7 Batch 1000 Loss 0.5933
# Epoch 7 Batch 1100 Loss 0.5807
# Epoch 7 Batch 1200 Loss 0.5659
# Epoch 7 Batch 1300 Loss 0.5855
# Epoch 7 Batch 1400 Loss 0.6428
# Epoch 7 Batch 1500 Loss 0.6315
# Epoch 7 Batch 1600 Loss 0.5555
# Epoch 7 Batch 1700 Loss 0.5805
# Epoch 7 Batch 1800 Loss 0.6034
# Epoch 7 Batch 1900 Loss 0.5978
# Epoch 7 Batch 2000 Loss 0.6421
# Epoch 7 Batch 2100 Loss 0.5534
# Epoch 7 Batch 2200 Loss 0.6603
# Epoch 7 Batch 2300 Loss 0.6060
# Epoch 7 Batch 2400 Loss 0.5777
# Epoch 7 Batch 2500 Loss 0.5857
# Epoch 7 Batch 2600 Loss 0.5874
# Epoch 7 Batch 2700 Loss 0.5930
# Epoch 7 Batch 2800 Loss 0.6019
# Epoch 7 Batch 2900 Loss 0.5573
# Epoch 7 Batch 3000 Loss 0.5908
# Epoch 7 Batch 3100 Loss 0.5875
# Epoch 7 Batch 3200 Loss 0.5815
# Epoch 7 Batch 3300 Loss 0.6174
# Epoch 7 Batch 3400 Loss 0.5685
# Epoch 7 Batch 3500 Loss 0.5689
# Epoch 7 Batch 3600 Loss 0.6297
# Epoch 7 Batch 3700 Loss 0.5926
# Epoch 7 Batch 3800 Loss 0.6077
# Epoch 7 Batch 3900 Loss 0.5409
# Epoch 7 Batch 4000 Loss 0.6120
# Epoch 7 Batch 4100 Loss 0.5739
# Epoch 7 Batch 4200 Loss 0.6608
# Epoch 7 Batch 4300 Loss 0.6205
# Epoch 7 Batch 4400 Loss 0.5218
# Epoch 7 Batch 4500 Loss 0.5773
# Epoch 7 Batch 4600 Loss 0.5567
# Epoch 7 Batch 4700 Loss 0.5964
# Epoch 7 Batch 4800 Loss 0.5918
# Epoch 7 Batch 4900 Loss 0.5767
# Epoch 7 Batch 5000 Loss 0.5294
# Epoch 7 Batch 5100 Loss 0.5827
# Epoch 7 Loss 0.589662
# Time taken for 1 epoch 1061.71 sec
#
# Epoch 8 Batch 0 Loss 0.5569
# Epoch 8 Batch 100 Loss 0.5958
# Epoch 8 Batch 200 Loss 0.5890
# Epoch 8 Batch 300 Loss 0.5499
# Epoch 8 Batch 400 Loss 0.6129
# Epoch 8 Batch 500 Loss 0.5855
# Epoch 8 Batch 600 Loss 0.5907
# Epoch 8 Batch 700 Loss 0.5884
# Epoch 8 Batch 800 Loss 0.5350
# Epoch 8 Batch 900 Loss 0.5509
# Epoch 8 Batch 1000 Loss 0.5846
# Epoch 8 Batch 1100 Loss 0.5930
# Epoch 8 Batch 1200 Loss 0.5398
# Epoch 8 Batch 1300 Loss 0.6154
# Epoch 8 Batch 1400 Loss 0.5590
# Epoch 8 Batch 1500 Loss 0.5172
# Epoch 8 Batch 1600 Loss 0.6044
# Epoch 8 Batch 1700 Loss 0.5631
# Epoch 8 Batch 1800 Loss 0.5560
# Epoch 8 Batch 1900 Loss 0.5961
# Epoch 8 Batch 2000 Loss 0.5854
# Epoch 8 Batch 2100 Loss 0.5927
# Epoch 8 Batch 2200 Loss 0.6414
# Epoch 8 Batch 2300 Loss 0.5653
# Epoch 8 Batch 2400 Loss 0.5930
# Epoch 8 Batch 2500 Loss 0.5924
# Epoch 8 Batch 2600 Loss 0.6077
# Epoch 8 Batch 2700 Loss 0.5365
# Epoch 8 Batch 2800 Loss 0.5892
# Epoch 8 Batch 2900 Loss 0.5943
# Epoch 8 Batch 3000 Loss 0.5810
# Epoch 8 Batch 3100 Loss 0.5540
# Epoch 8 Batch 3200 Loss 0.5737
# Epoch 8 Batch 3300 Loss 0.5647
# Epoch 8 Batch 3400 Loss 0.5721
# Epoch 8 Batch 3500 Loss 0.6033
# Epoch 8 Batch 3600 Loss 0.5609
# Epoch 8 Batch 3700 Loss 0.6232
# Epoch 8 Batch 3800 Loss 0.5033
# Epoch 8 Batch 3900 Loss 0.5741
# Epoch 8 Batch 4000 Loss 0.5539
# Epoch 8 Batch 4100 Loss 0.5670
# Epoch 8 Batch 4200 Loss 0.5721
# Epoch 8 Batch 4300 Loss 0.6076
# Epoch 8 Batch 4400 Loss 0.5773
# Epoch 8 Batch 4500 Loss 0.5975
# Epoch 8 Batch 4600 Loss 0.6124
# Epoch 8 Batch 4700 Loss 0.5975
# Epoch 8 Batch 4800 Loss 0.5240
# Epoch 8 Batch 4900 Loss 0.5190
# Epoch 8 Batch 5000 Loss 0.5624
# Epoch 8 Batch 5100 Loss 0.5853
# Epoch 8 Loss 0.571820
# Time taken for 1 epoch 1068.78 sec
#
# Epoch 9 Batch 0 Loss 0.6166
# Epoch 9 Batch 100 Loss 0.5530
# Epoch 9 Batch 200 Loss 0.5679
# Epoch 9 Batch 300 Loss 0.5859
# Epoch 9 Batch 400 Loss 0.5976
# Epoch 9 Batch 500 Loss 0.5785
# Epoch 9 Batch 600 Loss 0.6201
# Epoch 9 Batch 700 Loss 0.5559
# Epoch 9 Batch 800 Loss 0.6233
# Epoch 9 Batch 900 Loss 0.5211
# Epoch 9 Batch 1000 Loss 0.5937
# Epoch 9 Batch 1100 Loss 0.5976
# Epoch 9 Batch 1200 Loss 0.5890
# Epoch 9 Batch 1300 Loss 0.5461
# Epoch 9 Batch 1400 Loss 0.5833
# Epoch 9 Batch 1500 Loss 0.5584
# Epoch 9 Batch 1600 Loss 0.5324
# Epoch 9 Batch 1700 Loss 0.5138
# Epoch 9 Batch 1800 Loss 0.5345
# Epoch 9 Batch 1900 Loss 0.5263
# Epoch 9 Batch 2000 Loss 0.5352
# Epoch 9 Batch 2100 Loss 0.5237
# Epoch 9 Batch 2200 Loss 0.5421
# Epoch 9 Batch 2300 Loss 0.5710
# Epoch 9 Batch 2400 Loss 0.5661
# Epoch 9 Batch 2500 Loss 0.5887
# Epoch 9 Batch 2600 Loss 0.5255
# Epoch 9 Batch 2700 Loss 0.5352
# Epoch 9 Batch 2800 Loss 0.5414
# Epoch 9 Batch 2900 Loss 0.5658
# Epoch 9 Batch 3000 Loss 0.6021
# Epoch 9 Batch 3100 Loss 0.5154
# Epoch 9 Batch 3200 Loss 0.5133
# Epoch 9 Batch 3300 Loss 0.5521
# Epoch 9 Batch 3400 Loss 0.5711
# Epoch 9 Batch 3500 Loss 0.4999
# Epoch 9 Batch 3600 Loss 0.5255
# Epoch 9 Batch 3700 Loss 0.5904
# Epoch 9 Batch 3800 Loss 0.5514
# Epoch 9 Batch 3900 Loss 0.5662
# Epoch 9 Batch 4000 Loss 0.5272
# Epoch 9 Batch 4100 Loss 0.5487
# Epoch 9 Batch 4200 Loss 0.5195
# Epoch 9 Batch 4300 Loss 0.6152
# Epoch 9 Batch 4400 Loss 0.5515
# Epoch 9 Batch 4500 Loss 0.6123
# Epoch 9 Batch 4600 Loss 0.6061
# Epoch 9 Batch 4700 Loss 0.5291
# Epoch 9 Batch 4800 Loss 0.5612
# Epoch 9 Batch 4900 Loss 0.5490
# Epoch 9 Batch 5000 Loss 0.5304
# Epoch 9 Batch 5100 Loss 0.5243
# Epoch 9 Loss 0.557948
# Time taken for 1 epoch 1050.76 sec
#
# Epoch 10 Batch 0 Loss 0.5672
# Epoch 10 Batch 100 Loss 0.5627
# Epoch 10 Batch 200 Loss 0.5857
# Epoch 10 Batch 300 Loss 0.5308
# Epoch 10 Batch 400 Loss 0.5207
# Epoch 10 Batch 500 Loss 0.5353
# Epoch 10 Batch 600 Loss 0.5268
# Epoch 10 Batch 700 Loss 0.5354
# Epoch 10 Batch 800 Loss 0.5553
# Epoch 10 Batch 900 Loss 0.5525
# Epoch 10 Batch 1000 Loss 0.5974
# Epoch 10 Batch 1100 Loss 0.5810
# Epoch 10 Batch 1200 Loss 0.5244
# Epoch 10 Batch 1300 Loss 0.5592
# Epoch 10 Batch 1400 Loss 0.5091
# Epoch 10 Batch 1500 Loss 0.5504
# Epoch 10 Batch 1600 Loss 0.5273
# Epoch 10 Batch 1700 Loss 0.5518
# Epoch 10 Batch 1800 Loss 0.5898
# Epoch 10 Batch 1900 Loss 0.6188
# Epoch 10 Batch 2000 Loss 0.5735
# Epoch 10 Batch 2100 Loss 0.5196
# Epoch 10 Batch 2200 Loss 0.5274
# Epoch 10 Batch 2300 Loss 0.5567
# Epoch 10 Batch 2400 Loss 0.5456
# Epoch 10 Batch 2500 Loss 0.5492
# Epoch 10 Batch 2600 Loss 0.5127
# Epoch 10 Batch 2700 Loss 0.6056
# Epoch 10 Batch 2800 Loss 0.4915
# Epoch 10 Batch 2900 Loss 0.5128
# Epoch 10 Batch 3000 Loss 0.5019
# Epoch 10 Batch 3100 Loss 0.4773
# Epoch 10 Batch 3200 Loss 0.6163
# Epoch 10 Batch 3300 Loss 0.5723
# Epoch 10 Batch 3400 Loss 0.5957
# Epoch 10 Batch 3500 Loss 0.5221
# Epoch 10 Batch 3600 Loss 0.5616
# Epoch 10 Batch 3700 Loss 0.5404
# Epoch 10 Batch 3800 Loss 0.5419
# Epoch 10 Batch 3900 Loss 0.4891
# Epoch 10 Batch 4000 Loss 0.5421
# Epoch 10 Batch 4100 Loss 0.5731
# Epoch 10 Batch 4200 Loss 0.5645
# Epoch 10 Batch 4300 Loss 0.4987
# Epoch 10 Batch 4400 Loss 0.4949
# Epoch 10 Batch 4500 Loss 0.5551
# Epoch 10 Batch 4600 Loss 0.5044
# Epoch 10 Batch 4700 Loss 0.5273
# Epoch 10 Batch 4800 Loss 0.5357
# Epoch 10 Batch 4900 Loss 0.5678
# Epoch 10 Batch 5000 Loss 0.5491
# Epoch 10 Batch 5100 Loss 0.5403
# Epoch 10 Loss 0.546158
# Time taken for 1 epoch 1047.92 sec
#
# Epoch 11 Batch 0 Loss 0.5751
# Epoch 11 Batch 100 Loss 0.5026
# Epoch 11 Batch 200 Loss 0.5646
# Epoch 11 Batch 300 Loss 0.6013
# Epoch 11 Batch 400 Loss 0.5211
# Epoch 11 Batch 500 Loss 0.5439
# Epoch 11 Batch 600 Loss 0.5509
# Epoch 11 Batch 700 Loss 0.5135
# Epoch 11 Batch 800 Loss 0.5415
# Epoch 11 Batch 900 Loss 0.5946
# Epoch 11 Batch 1000 Loss 0.5407
# Epoch 11 Batch 1100 Loss 0.5432
# Epoch 11 Batch 1200 Loss 0.5547
# Epoch 11 Batch 1300 Loss 0.5395
# Epoch 11 Batch 1400 Loss 0.4992
# Epoch 11 Batch 1500 Loss 0.5162
# Epoch 11 Batch 1600 Loss 0.5729
# Epoch 11 Batch 1700 Loss 0.5504
# Epoch 11 Batch 1800 Loss 0.5709
# Epoch 11 Batch 1900 Loss 0.5110
# Epoch 11 Batch 2000 Loss 0.5579
# Epoch 11 Batch 2100 Loss 0.5506
# Epoch 11 Batch 2200 Loss 0.5235
# Epoch 11 Batch 2300 Loss 0.5341
# Epoch 11 Batch 2400 Loss 0.5360
# Epoch 11 Batch 2500 Loss 0.5525
# Epoch 11 Batch 2600 Loss 0.5244
# Epoch 11 Batch 2700 Loss 0.5057
# Epoch 11 Batch 2800 Loss 0.5199
# Epoch 11 Batch 2900 Loss 0.5441
# Epoch 11 Batch 3000 Loss 0.5239
# Epoch 11 Batch 3100 Loss 0.5314
# Epoch 11 Batch 3200 Loss 0.5841
# Epoch 11 Batch 3300 Loss 0.5635
# Epoch 11 Batch 3400 Loss 0.5446
# Epoch 11 Batch 3500 Loss 0.4937
# Epoch 11 Batch 3600 Loss 0.5202
# Epoch 11 Batch 3700 Loss 0.5061
# Epoch 11 Batch 3800 Loss 0.5078
# Epoch 11 Batch 3900 Loss 0.5166
# Epoch 11 Batch 4000 Loss 0.5481
# Epoch 11 Batch 4100 Loss 0.5156
# Epoch 11 Batch 4200 Loss 0.5937
# Epoch 11 Batch 4300 Loss 0.5292
# Epoch 11 Batch 4400 Loss 0.5787
# Epoch 11 Batch 4500 Loss 0.5794
# Epoch 11 Batch 4600 Loss 0.5243
# Epoch 11 Batch 4700 Loss 0.5794
# Epoch 11 Batch 4800 Loss 0.5803
# Epoch 11 Batch 4900 Loss 0.5341
# Epoch 11 Batch 5000 Loss 0.5178
# Epoch 11 Batch 5100 Loss 0.5517
# Epoch 11 Loss 0.536158
# Time taken for 1 epoch 1050.56 sec
#
# Epoch 12 Batch 0 Loss 0.5466
# Epoch 12 Batch 100 Loss 0.5543
# Epoch 12 Batch 200 Loss 0.5142
# Epoch 12 Batch 300 Loss 0.5265
# Epoch 12 Batch 400 Loss 0.4892
# Epoch 12 Batch 500 Loss 0.5135
# Epoch 12 Batch 600 Loss 0.5823
# Epoch 12 Batch 700 Loss 0.5087
# Epoch 12 Batch 800 Loss 0.4422
# Epoch 12 Batch 900 Loss 0.5687
# Epoch 12 Batch 1000 Loss 0.5295
# Epoch 12 Batch 1100 Loss 0.4825
# Epoch 12 Batch 1200 Loss 0.5427
# Epoch 12 Batch 1300 Loss 0.5500
# Epoch 12 Batch 1400 Loss 0.5300
# Epoch 12 Batch 1500 Loss 0.5830
# Epoch 12 Batch 1600 Loss 0.5679
# Epoch 12 Batch 1700 Loss 0.5463
# Epoch 12 Batch 1800 Loss 0.5469
# Epoch 12 Batch 1900 Loss 0.5413
# Epoch 12 Batch 2000 Loss 0.6013
# Epoch 12 Batch 2100 Loss 0.5581
# Epoch 12 Batch 2200 Loss 0.5533
# Epoch 12 Batch 2300 Loss 0.5581
# Epoch 12 Batch 2400 Loss 0.5013
# Epoch 12 Batch 2500 Loss 0.5152
# Epoch 12 Batch 2600 Loss 0.4836
# Epoch 12 Batch 2700 Loss 0.5422
# Epoch 12 Batch 2800 Loss 0.5190
# Epoch 12 Batch 2900 Loss 0.5568
# Epoch 12 Batch 3000 Loss 0.5096
# Epoch 12 Batch 3100 Loss 0.4613
# Epoch 12 Batch 3200 Loss 0.5521
# Epoch 12 Batch 3300 Loss 0.5821
# Epoch 12 Batch 3400 Loss 0.4866
# Epoch 12 Batch 3500 Loss 0.5347
# Epoch 12 Batch 3600 Loss 0.5472
# Epoch 12 Batch 3700 Loss 0.5338
# Epoch 12 Batch 3800 Loss 0.5412
# Epoch 12 Batch 3900 Loss 0.5795
# Epoch 12 Batch 4000 Loss 0.5467
# Epoch 12 Batch 4100 Loss 0.5333
# Epoch 12 Batch 4200 Loss 0.5384
# Epoch 12 Batch 4300 Loss 0.5670
# Epoch 12 Batch 4400 Loss 0.5448
# Epoch 12 Batch 4500 Loss 0.5299
# Epoch 12 Batch 4600 Loss 0.5401
# Epoch 12 Batch 4700 Loss 0.4899
# Epoch 12 Batch 4800 Loss 0.5716
# Epoch 12 Batch 4900 Loss 0.5488
# Epoch 12 Batch 5000 Loss 0.5303
# Epoch 12 Batch 5100 Loss 0.5358
# Epoch 12 Loss 0.527169
# Time taken for 1 epoch 1047.10 sec
#
# Epoch 13 Batch 0 Loss 0.5338
# Epoch 13 Batch 100 Loss 0.4967
# Epoch 13 Batch 200 Loss 0.5785
# Epoch 13 Batch 300 Loss 0.5459
# Epoch 13 Batch 400 Loss 0.4994
# Epoch 13 Batch 500 Loss 0.5446
# Epoch 13 Batch 600 Loss 0.4792
# Epoch 13 Batch 700 Loss 0.5197
# Epoch 13 Batch 800 Loss 0.5702
# Epoch 13 Batch 900 Loss 0.5326
# Epoch 13 Batch 1000 Loss 0.5464
# Epoch 13 Batch 1100 Loss 0.5590
# Epoch 13 Batch 1200 Loss 0.5040
# Epoch 13 Batch 1300 Loss 0.5162
# Epoch 13 Batch 1400 Loss 0.5623
# Epoch 13 Batch 1500 Loss 0.5393
# Epoch 13 Batch 1600 Loss 0.4998
# Epoch 13 Batch 1700 Loss 0.4926
# Epoch 13 Batch 1800 Loss 0.5216
# Epoch 13 Batch 1900 Loss 0.5279
# Epoch 13 Batch 2000 Loss 0.4948
# Epoch 13 Batch 2100 Loss 0.5235
# Epoch 13 Batch 2200 Loss 0.5373
# Epoch 13 Batch 2300 Loss 0.4812
# Epoch 13 Batch 2400 Loss 0.4874
# Epoch 13 Batch 2500 Loss 0.5278
# Epoch 13 Batch 2600 Loss 0.5232
# Epoch 13 Batch 2700 Loss 0.4521
# Epoch 13 Batch 2800 Loss 0.5060
# Epoch 13 Batch 2900 Loss 0.4882
# Epoch 13 Batch 3000 Loss 0.5353
# Epoch 13 Batch 3100 Loss 0.5660
# Epoch 13 Batch 3200 Loss 0.5509
# Epoch 13 Batch 3300 Loss 0.5140
# Epoch 13 Batch 3400 Loss 0.5136
# Epoch 13 Batch 3500 Loss 0.5356
# Epoch 13 Batch 3600 Loss 0.5283
# Epoch 13 Batch 3700 Loss 0.5063
# Epoch 13 Batch 3800 Loss 0.4987
# Epoch 13 Batch 3900 Loss 0.4724
# Epoch 13 Batch 4000 Loss 0.5605
# Epoch 13 Batch 4100 Loss 0.4944
# Epoch 13 Batch 4200 Loss 0.4894
# Epoch 13 Batch 4300 Loss 0.4982
# Epoch 13 Batch 4400 Loss 0.5247
# Epoch 13 Batch 4500 Loss 0.5023
# Epoch 13 Batch 4600 Loss 0.4980
# Epoch 13 Batch 4700 Loss 0.5128
# Epoch 13 Batch 4800 Loss 0.5420
# Epoch 13 Batch 4900 Loss 0.4786
# Epoch 13 Batch 5000 Loss 0.5112
# Epoch 13 Batch 5100 Loss 0.5306
# Epoch 13 Loss 0.519111
# Time taken for 1 epoch 1065.16 sec
#
# Epoch 14 Batch 0 Loss 0.5277
# Epoch 14 Batch 100 Loss 0.5066
# Epoch 14 Batch 200 Loss 0.4824
# Epoch 14 Batch 300 Loss 0.5080
# Epoch 14 Batch 400 Loss 0.5189
# Epoch 14 Batch 500 Loss 0.5258
# Epoch 14 Batch 600 Loss 0.5171
# Epoch 14 Batch 700 Loss 0.5204
# Epoch 14 Batch 800 Loss 0.5720
# Epoch 14 Batch 900 Loss 0.5016
# Epoch 14 Batch 1000 Loss 0.5493
# Epoch 14 Batch 1100 Loss 0.5326
# Epoch 14 Batch 1200 Loss 0.5330
# Epoch 14 Batch 1300 Loss 0.4873
# Epoch 14 Batch 1400 Loss 0.5152
# Epoch 14 Batch 1500 Loss 0.5041
# Epoch 14 Batch 1600 Loss 0.5519
# Epoch 14 Batch 1700 Loss 0.5329
# Epoch 14 Batch 1800 Loss 0.4581
# Epoch 14 Batch 1900 Loss 0.5590
# Epoch 14 Batch 2000 Loss 0.4670
# Epoch 14 Batch 2100 Loss 0.5234
# Epoch 14 Batch 2200 Loss 0.5583
# Epoch 14 Batch 2300 Loss 0.5180
# Epoch 14 Batch 2400 Loss 0.5025
# Epoch 14 Batch 2500 Loss 0.4991
# Epoch 14 Batch 2600 Loss 0.4984
# Epoch 14 Batch 2700 Loss 0.4907
# Epoch 14 Batch 2800 Loss 0.4876
# Epoch 14 Batch 2900 Loss 0.5275
# Epoch 14 Batch 3000 Loss 0.4889
# Epoch 14 Batch 3100 Loss 0.5180
# Epoch 14 Batch 3200 Loss 0.5107
# Epoch 14 Batch 3300 Loss 0.4699
# Epoch 14 Batch 3400 Loss 0.5004
# Epoch 14 Batch 3500 Loss 0.5263
# Epoch 14 Batch 3600 Loss 0.5031
# Epoch 14 Batch 3700 Loss 0.5114
# Epoch 14 Batch 3800 Loss 0.5698
# Epoch 14 Batch 3900 Loss 0.5026
# Epoch 14 Batch 4000 Loss 0.5100
# Epoch 14 Batch 4100 Loss 0.5067
# Epoch 14 Batch 4200 Loss 0.5377
# Epoch 14 Batch 4300 Loss 0.4946
# Epoch 14 Batch 4400 Loss 0.5332
# Epoch 14 Batch 4500 Loss 0.5019
# Epoch 14 Batch 4600 Loss 0.5198
# Epoch 14 Batch 4700 Loss 0.5194
# Epoch 14 Batch 4800 Loss 0.5135
# Epoch 14 Batch 4900 Loss 0.4821
# Epoch 14 Batch 5000 Loss 0.4851
# Epoch 14 Batch 5100 Loss 0.5618
# Epoch 14 Loss 0.511741
# Time taken for 1 epoch 1037.33 sec
#
# Epoch 15 Batch 0 Loss 0.5288
# Epoch 15 Batch 100 Loss 0.4781
# Epoch 15 Batch 200 Loss 0.4994
# Epoch 15 Batch 300 Loss 0.4428
# Epoch 15 Batch 400 Loss 0.5196
# Epoch 15 Batch 500 Loss 0.5142
# Epoch 15 Batch 600 Loss 0.5142
# Epoch 15 Batch 700 Loss 0.5427
# Epoch 15 Batch 800 Loss 0.5064
# Epoch 15 Batch 900 Loss 0.5043
# Epoch 15 Batch 1000 Loss 0.5190
# Epoch 15 Batch 1100 Loss 0.4861
# Epoch 15 Batch 1200 Loss 0.4830
# Epoch 15 Batch 1300 Loss 0.5638
# Epoch 15 Batch 1400 Loss 0.4851
# Epoch 15 Batch 1500 Loss 0.4928
# Epoch 15 Batch 1600 Loss 0.5409
# Epoch 15 Batch 1700 Loss 0.5363
# Epoch 15 Batch 1800 Loss 0.4404
# Epoch 15 Batch 1900 Loss 0.5197
# Epoch 15 Batch 2000 Loss 0.5330
# Epoch 15 Batch 2100 Loss 0.4468
# Epoch 15 Batch 2200 Loss 0.5641
# Epoch 15 Batch 2300 Loss 0.5249
# Epoch 15 Batch 2400 Loss 0.4597
# Epoch 15 Batch 2500 Loss 0.4971
# Epoch 15 Batch 2600 Loss 0.4847
# Epoch 15 Batch 2700 Loss 0.5137
# Epoch 15 Batch 2800 Loss 0.4781
# Epoch 15 Batch 2900 Loss 0.4709
# Epoch 15 Batch 3000 Loss 0.4819
# Epoch 15 Batch 3100 Loss 0.5071
# Epoch 15 Batch 3200 Loss 0.5575
# Epoch 15 Batch 3300 Loss 0.4102
# Epoch 15 Batch 3400 Loss 0.5088
# Epoch 15 Batch 3500 Loss 0.5204
# Epoch 15 Batch 3600 Loss 0.5155
# Epoch 15 Batch 3700 Loss 0.4740
# Epoch 15 Batch 3800 Loss 0.4926
# Epoch 15 Batch 3900 Loss 0.5088
# Epoch 15 Batch 4000 Loss 0.5319
# Epoch 15 Batch 4100 Loss 0.4838
# Epoch 15 Batch 4200 Loss 0.4636
# Epoch 15 Batch 4300 Loss 0.5554
# Epoch 15 Batch 4400 Loss 0.4906
# Epoch 15 Batch 4500 Loss 0.5338
# Epoch 15 Batch 4600 Loss 0.4849
# Epoch 15 Batch 4700 Loss 0.4890
# Epoch 15 Batch 4800 Loss 0.5121
# Epoch 15 Batch 4900 Loss 0.4797
# Epoch 15 Batch 5000 Loss 0.5064
# Epoch 15 Batch 5100 Loss 0.5075
# Epoch 15 Loss 0.505132
# Time taken for 1 epoch 1052.97 sec
#
# Epoch 16 Batch 0 Loss 0.4931
# Epoch 16 Batch 100 Loss 0.4946
# Epoch 16 Batch 200 Loss 0.5311
# Epoch 16 Batch 300 Loss 0.4879
# Epoch 16 Batch 400 Loss 0.5026
# Epoch 16 Batch 500 Loss 0.5301
# Epoch 16 Batch 600 Loss 0.5154
# Epoch 16 Batch 700 Loss 0.5008
# Epoch 16 Batch 800 Loss 0.4795
# Epoch 16 Batch 900 Loss 0.4909
# Epoch 16 Batch 1000 Loss 0.5369
# Epoch 16 Batch 1100 Loss 0.5470
# Epoch 16 Batch 1200 Loss 0.4834
# Epoch 16 Batch 1300 Loss 0.5461
# Epoch 16 Batch 1400 Loss 0.5172
# Epoch 16 Batch 1500 Loss 0.5124
# Epoch 16 Batch 1600 Loss 0.5459
# Epoch 16 Batch 1700 Loss 0.4694
# Epoch 16 Batch 1800 Loss 0.4928
# Epoch 16 Batch 1900 Loss 0.4965
# Epoch 16 Batch 2000 Loss 0.5105
# Epoch 16 Batch 2100 Loss 0.4904
# Epoch 16 Batch 2200 Loss 0.5161
# Epoch 16 Batch 2300 Loss 0.5358
# Epoch 16 Batch 2400 Loss 0.5062
# Epoch 16 Batch 2500 Loss 0.4625
# Epoch 16 Batch 2600 Loss 0.4871
# Epoch 16 Batch 2700 Loss 0.4793
# Epoch 16 Batch 2800 Loss 0.4918
# Epoch 16 Batch 2900 Loss 0.4777
# Epoch 16 Batch 3000 Loss 0.5162
# Epoch 16 Batch 3100 Loss 0.4726
# Epoch 16 Batch 3200 Loss 0.4990
# Epoch 16 Batch 3300 Loss 0.5386
# Epoch 16 Batch 3400 Loss 0.4721
# Epoch 16 Batch 3500 Loss 0.5148
# Epoch 16 Batch 3600 Loss 0.5148
# Epoch 16 Batch 3700 Loss 0.5167
# Epoch 16 Batch 3800 Loss 0.4934
# Epoch 16 Batch 3900 Loss 0.4930
# Epoch 16 Batch 4000 Loss 0.4740
# Epoch 16 Batch 4100 Loss 0.4538
# Epoch 16 Batch 4200 Loss 0.4993
# Epoch 16 Batch 4300 Loss 0.5238
# Epoch 16 Batch 4400 Loss 0.4672
# Epoch 16 Batch 4500 Loss 0.5120
# Epoch 16 Batch 4600 Loss 0.4971
# Epoch 16 Batch 4700 Loss 0.5050
# Epoch 16 Batch 4800 Loss 0.5639
# Epoch 16 Batch 4900 Loss 0.4846
# Epoch 16 Batch 5000 Loss 0.5099
# Epoch 16 Batch 5100 Loss 0.5563
# Epoch 16 Loss 0.499045
# Time taken for 1 epoch 1040.94 sec
#
# Epoch 17 Batch 0 Loss 0.5351
# Epoch 17 Batch 100 Loss 0.5195
# Epoch 17 Batch 200 Loss 0.5104
# Epoch 17 Batch 300 Loss 0.4765
# Epoch 17 Batch 400 Loss 0.4662
# Epoch 17 Batch 500 Loss 0.4408
# Epoch 17 Batch 600 Loss 0.5262
# Epoch 17 Batch 700 Loss 0.4847
# Epoch 17 Batch 800 Loss 0.4820
# Epoch 17 Batch 900 Loss 0.5143
# Epoch 17 Batch 1000 Loss 0.5443
# Epoch 17 Batch 1100 Loss 0.5048
# Epoch 17 Batch 1200 Loss 0.4486
# Epoch 17 Batch 1300 Loss 0.5215
# Epoch 17 Batch 1400 Loss 0.5491
# Epoch 17 Batch 1500 Loss 0.4819
# Epoch 17 Batch 1600 Loss 0.5317
# Epoch 17 Batch 1700 Loss 0.4762
# Epoch 17 Batch 1800 Loss 0.4319
# Epoch 17 Batch 1900 Loss 0.5301
# Epoch 17 Batch 2000 Loss 0.4802
# Epoch 17 Batch 2100 Loss 0.4527
# Epoch 17 Batch 2200 Loss 0.5157
# Epoch 17 Batch 2300 Loss 0.5178
# Epoch 17 Batch 2400 Loss 0.4906
# Epoch 17 Batch 2500 Loss 0.5079
# Epoch 17 Batch 2600 Loss 0.4189
# Epoch 17 Batch 2700 Loss 0.4832
# Epoch 17 Batch 2800 Loss 0.4799
# Epoch 17 Batch 2900 Loss 0.4798
# Epoch 17 Batch 3000 Loss 0.4885
# Epoch 17 Batch 3100 Loss 0.4953
# Epoch 17 Batch 3200 Loss 0.5159
# Epoch 17 Batch 3300 Loss 0.4705
# Epoch 17 Batch 3400 Loss 0.5060
# Epoch 17 Batch 3500 Loss 0.4665
# Epoch 17 Batch 3600 Loss 0.4872
# Epoch 17 Batch 3700 Loss 0.4789
# Epoch 17 Batch 3800 Loss 0.4799
# Epoch 17 Batch 3900 Loss 0.5366
# Epoch 17 Batch 4000 Loss 0.4373
# Epoch 17 Batch 4100 Loss 0.5007
# Epoch 17 Batch 4200 Loss 0.4648
# Epoch 17 Batch 4300 Loss 0.5187
# Epoch 17 Batch 4400 Loss 0.4802
# Epoch 17 Batch 4500 Loss 0.4779
# Epoch 17 Batch 4600 Loss 0.4904
# Epoch 17 Batch 4700 Loss 0.5009
# Epoch 17 Batch 4800 Loss 0.5579
# Epoch 17 Batch 4900 Loss 0.5042
# Epoch 17 Batch 5000 Loss 0.4834
# Epoch 17 Batch 5100 Loss 0.5613
# Epoch 17 Loss 0.493811
# Time taken for 1 epoch 1056.05 sec
#
# Epoch 18 Batch 0 Loss 0.4994
# Epoch 18 Batch 100 Loss 0.5043
# Epoch 18 Batch 200 Loss 0.4819
# Epoch 18 Batch 300 Loss 0.4889
# Epoch 18 Batch 400 Loss 0.5072
# Epoch 18 Batch 500 Loss 0.4768
# Epoch 18 Batch 600 Loss 0.4927
# Epoch 18 Batch 700 Loss 0.4856
# Epoch 18 Batch 800 Loss 0.4750
# Epoch 18 Batch 900 Loss 0.5834
# Epoch 18 Batch 1000 Loss 0.5328
# Epoch 18 Batch 1100 Loss 0.4937
# Epoch 18 Batch 1200 Loss 0.5408
# Epoch 18 Batch 1300 Loss 0.4406
# Epoch 18 Batch 1400 Loss 0.4756
# Epoch 18 Batch 1500 Loss 0.4565
# Epoch 18 Batch 1600 Loss 0.4882
# Epoch 18 Batch 1700 Loss 0.4809
# Epoch 18 Batch 1800 Loss 0.4718
# Epoch 18 Batch 1900 Loss 0.5111
# Epoch 18 Batch 2000 Loss 0.5047
# Epoch 18 Batch 2100 Loss 0.4878
# Epoch 18 Batch 2200 Loss 0.5039
# Epoch 18 Batch 2300 Loss 0.4882
# Epoch 18 Batch 2400 Loss 0.4614
# Epoch 18 Batch 2500 Loss 0.5172
# Epoch 18 Batch 2600 Loss 0.5544
# Epoch 18 Batch 2700 Loss 0.5041
# Epoch 18 Batch 2800 Loss 0.5485
# Epoch 18 Batch 2900 Loss 0.4789
# Epoch 18 Batch 3000 Loss 0.4568
# Epoch 18 Batch 3100 Loss 0.5016
# Epoch 18 Batch 3200 Loss 0.4909
# Epoch 18 Batch 3300 Loss 0.4656
# Epoch 18 Batch 3400 Loss 0.5154
# Epoch 18 Batch 3500 Loss 0.5516
# Epoch 18 Batch 3600 Loss 0.5279
# Epoch 18 Batch 3700 Loss 0.4806
# Epoch 18 Batch 3800 Loss 0.4605
# Epoch 18 Batch 3900 Loss 0.4763
# Epoch 18 Batch 4000 Loss 0.4926
# Epoch 18 Batch 4100 Loss 0.5263
# Epoch 18 Batch 4200 Loss 0.4701
# Epoch 18 Batch 4300 Loss 0.4785
# Epoch 18 Batch 4400 Loss 0.4868
# Epoch 18 Batch 4500 Loss 0.4698
# Epoch 18 Batch 4600 Loss 0.4746
# Epoch 18 Batch 4700 Loss 0.5207
# Epoch 18 Batch 4800 Loss 0.5135
# Epoch 18 Batch 4900 Loss 0.4986
# Epoch 18 Batch 5000 Loss 0.5043
# Epoch 18 Batch 5100 Loss 0.4902
# Epoch 18 Loss 0.488762
# Time taken for 1 epoch 1063.31 sec
#
# Epoch 19 Batch 0 Loss 0.5087
# Epoch 19 Batch 100 Loss 0.5126
# Epoch 19 Batch 200 Loss 0.5308
# Epoch 19 Batch 300 Loss 0.5235
# Epoch 19 Batch 400 Loss 0.5076
# Epoch 19 Batch 500 Loss 0.4766
# Epoch 19 Batch 600 Loss 0.5054
# Epoch 19 Batch 700 Loss 0.4963
# Epoch 19 Batch 800 Loss 0.4721
# Epoch 19 Batch 900 Loss 0.4993
# Epoch 19 Batch 1000 Loss 0.5140
# Epoch 19 Batch 1100 Loss 0.5328
# Epoch 19 Batch 1200 Loss 0.4957
# Epoch 19 Batch 1300 Loss 0.4833
# Epoch 19 Batch 1400 Loss 0.4613
# Epoch 19 Batch 1500 Loss 0.5363
# Epoch 19 Batch 1600 Loss 0.5003
# Epoch 19 Batch 1700 Loss 0.4768
# Epoch 19 Batch 1800 Loss 0.4645
# Epoch 19 Batch 1900 Loss 0.5056
# Epoch 19 Batch 2000 Loss 0.4961
# Epoch 19 Batch 2100 Loss 0.4828
# Epoch 19 Batch 2200 Loss 0.4776
# Epoch 19 Batch 2300 Loss 0.5100
# Epoch 19 Batch 2400 Loss 0.5188
# Epoch 19 Batch 2500 Loss 0.4959
# Epoch 19 Batch 2600 Loss 0.4363
# Epoch 19 Batch 2700 Loss 0.4748
# Epoch 19 Batch 2800 Loss 0.5044
# Epoch 19 Batch 2900 Loss 0.4649
# Epoch 19 Batch 3000 Loss 0.5288
# Epoch 19 Batch 3100 Loss 0.4659
# Epoch 19 Batch 3200 Loss 0.5143
# Epoch 19 Batch 3300 Loss 0.4519
# Epoch 19 Batch 3400 Loss 0.5194
# Epoch 19 Batch 3500 Loss 0.4937
# Epoch 19 Batch 3600 Loss 0.4605
# Epoch 19 Batch 3700 Loss 0.4415
# Epoch 19 Batch 3800 Loss 0.4878
# Epoch 19 Batch 3900 Loss 0.4589
# Epoch 19 Batch 4000 Loss 0.4620
# Epoch 19 Batch 4100 Loss 0.4843
# Epoch 19 Batch 4200 Loss 0.5383
# Epoch 19 Batch 4300 Loss 0.4660
# Epoch 19 Batch 4400 Loss 0.5049
# Epoch 19 Batch 4500 Loss 0.4903
# Epoch 19 Batch 4600 Loss 0.4856
# Epoch 19 Batch 4700 Loss 0.4932
# Epoch 19 Batch 4800 Loss 0.4729
# Epoch 19 Batch 4900 Loss 0.4856
# Epoch 19 Batch 5000 Loss 0.4914
# Epoch 19 Batch 5100 Loss 0.4823
# Epoch 19 Loss 0.484109
# Time taken for 1 epoch 1072.33 sec
#
# Epoch 20 Batch 0 Loss 0.4942
# Epoch 20 Batch 100 Loss 0.4930
# Epoch 20 Batch 200 Loss 0.4934
# Epoch 20 Batch 300 Loss 0.4638
# Epoch 20 Batch 400 Loss 0.5086
# Epoch 20 Batch 500 Loss 0.4783
# Epoch 20 Batch 600 Loss 0.4850
# Epoch 20 Batch 700 Loss 0.4920
# Epoch 20 Batch 800 Loss 0.5206
# Epoch 20 Batch 900 Loss 0.5079
# Epoch 20 Batch 1000 Loss 0.4843
# Epoch 20 Batch 1100 Loss 0.4921
# Epoch 20 Batch 1200 Loss 0.4873
# Epoch 20 Batch 1300 Loss 0.5002
# Epoch 20 Batch 1400 Loss 0.5192
# Epoch 20 Batch 1500 Loss 0.4948
# Epoch 20 Batch 1600 Loss 0.4731
# Epoch 20 Batch 1700 Loss 0.4784
# Epoch 20 Batch 1800 Loss 0.5159
# Epoch 20 Batch 1900 Loss 0.5218
# Epoch 20 Batch 2000 Loss 0.4662
# Epoch 20 Batch 2100 Loss 0.5021
# Epoch 20 Batch 2200 Loss 0.4495
# Epoch 20 Batch 2300 Loss 0.4795
# Epoch 20 Batch 2400 Loss 0.4706
# Epoch 20 Batch 2500 Loss 0.4881
# Epoch 20 Batch 2600 Loss 0.4755
# Epoch 20 Batch 2700 Loss 0.4443
# Epoch 20 Batch 2800 Loss 0.4415
# Epoch 20 Batch 2900 Loss 0.4674
# Epoch 20 Batch 3000 Loss 0.4979
# Epoch 20 Batch 3100 Loss 0.4542
# Epoch 20 Batch 3200 Loss 0.4532
# Epoch 20 Batch 3300 Loss 0.4846
# Epoch 20 Batch 3400 Loss 0.5075
# Epoch 20 Batch 3500 Loss 0.4673
# Epoch 20 Batch 3600 Loss 0.4925
# Epoch 20 Batch 3700 Loss 0.4801
# Epoch 20 Batch 3800 Loss 0.4426
# Epoch 20 Batch 3900 Loss 0.5010
# Epoch 20 Batch 4000 Loss 0.4775
# Epoch 20 Batch 4100 Loss 0.4508
# Epoch 20 Batch 4200 Loss 0.4331
# Epoch 20 Batch 4300 Loss 0.4425
# Epoch 20 Batch 4400 Loss 0.4652
# Epoch 20 Batch 4500 Loss 0.4276
# Epoch 20 Batch 4600 Loss 0.4681
# Epoch 20 Batch 4700 Loss 0.4836
# Epoch 20 Batch 4800 Loss 0.5143
# Epoch 20 Batch 4900 Loss 0.4801
# Epoch 20 Batch 5000 Loss 0.4930
# Epoch 20 Batch 5100 Loss 0.4768
# Epoch 20 Loss 0.479924
# Time taken for 1 epoch 1065.09 sec

# %% [markdown]
# ## Graphs

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# ## Evaluate

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0],
                                                 -1,
                                                 img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([word_to_index('<start>')], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input,
                                                         features,
                                                         hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        predicted_word = tf.compat.as_text(index_to_word(predicted_id).numpy())
        result.append(predicted_word)

        if predicted_word == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for i in range(len_result):
        temp_att = np.resize(attention_plot[i], (8, 8))
        grid_size = max(int(np.ceil(len_result/2)), 2)
        ax = fig.add_subplot(grid_size, grid_size, i+1)
        ax.set_title(result[i])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy())
                         for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a picture of a white thing on top of a cloth. <end>
# Prediction Caption: two stuffed animals hanging in a pile of luggage <end>

# %% [markdown]
# ## Try on TouNum Photos

# %%
tounum_path = 'data/1_data_cat_thomas/val/photo/'
tounum_images = os.listdir(tounum_path)

# %%
for image_path in tounum_images[:10]:
    result, attention_plot = evaluate(tounum_path + image_path)
    print('Prediction Caption:', ' '.join(result))
    plot_attention(tounum_path + image_path, result, attention_plot)
    # opening the image
    Image.open(tounum_path + image_path)
# Out:
# Prediction Caption: a motorcycle is resting on a [UNK] <end>
# Prediction Caption: a person that air skate park heading of a man riding a skateboard down a wooden ramp. <end>
# Prediction Caption: a surfer in the air while riding a pile of water. <end>
# Prediction Caption: a train on a train track. <end>
# Prediction Caption: two people are riding on horses <end>
# Prediction Caption: grand [UNK] [UNK] [UNK] to enter sign pole. <end>
# Prediction Caption: a happy person on a bed in a closet sticking their hand on the wall standing with his dog on her arm. <end>
# Prediction Caption: the big ben clock tower on a building. <end>
# Prediction Caption: a bus is sitting on the street corner. <end>
# Prediction Caption: a city bus with lights and a huge billboard opposite directions. <end>

# %%
import datetime
import pandas as pd

date:datetime = datetime.datetime.now().strftime("%m.%d.%Y_%H:%M:%S")
model_dir:str = f"models/cap_encoder_{date}"
encoder.save(model_dir)
date:datetime = datetime.datetime.now().strftime("%m.%d.%Y_%H:%M:%S")
model_dir:str = f"models/cap_decoder_{date}"
decoder.save(model_dir)
