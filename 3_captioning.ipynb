# %% [markdown]
# # Deliverable 3 - Captioning

# %% [markdown]
# ## Import

# %%
# Disable Tensorflow's warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import collections
import random
import numpy as np
import os
import time
import json
from PIL import Image
import pickle
# Out:
# 2022-10-21 00:12:06.003048: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Load COCO Dataset

# %%
annotation_file = 'data/3_annotations/captions_train2014.json'
image_folder = 'data/3_train2014/'

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
  caption = f"<start> {val['caption']} <end>"
  image_path = image_folder + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
  image_path_to_caption[image_path].append(caption)

image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# %%
# Select the first 50000 image_paths from the shuffled set.
train_image_paths = image_paths[:50000]

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
  caption_list = image_path_to_caption[image_path]
  train_captions.extend(caption_list)
  img_name_vector.extend([image_path] * len(caption_list))

print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> Filtered photograph of boat and person windsurfing in ocean. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x612>

# %% [markdown]
# ## Load InceptionV3 model

# %%
# Load CNN part of the Inception model 
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')

# Take Input layer of Inception                                                
new_input = image_model.input
# Take Output layer of Inception (last CNN layer)   
hidden_layer = image_model.layers[-1].output

# Create a model that will create image vector for the RNN
image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %% [markdown]
# ## Preprocessing Images with InceptionV3

# %%
# Convert images at format expected by InceptionV3 (image 299px by 299px, and pixels between -1 and 1)
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.keras.layers.Resizing(299, 299)(img)
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Convert image set to Dataset
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)

# Preprocess each image with InceptionV3 and cache it
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

# Save preprocessed images
for img, path in image_dataset:
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())

# %% [markdown]
# ## Preprocessing and tokenize subtitles

# %%
caption_dataset = tf.data.Dataset.from_tensor_slices(train_captions)

# Standardize captions (lowercase, clean odd characters)
def standardize(inputs):
  inputs = tf.strings.lower(inputs)
  return tf.strings.regex_replace(inputs,
                                  r"!\"#$%&\(\)\*\+.,-/:;=?@\[\\\]^_`{|}~", "")

# Max number of word for a caption.
max_length = 8
# Use the top 5000 words for a vocabulary.
vocabulary_size = 5000
tokenizer = tf.keras.layers.TextVectorization(
    max_tokens=vocabulary_size,
    standardize=standardize,
    output_sequence_length=max_length)
# Learn the vocabulary from the caption data.
tokenizer.adapt(caption_dataset)

# Create the tokenized vectors
cap_vector = caption_dataset.map(lambda x: tokenizer(x))

# Create mappings for words to indices and indicies to words.
word_to_index = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary())
index_to_word = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary(),
    invert=True)

# %%
# Save train captions for the pipeline
with open('data/3_train_captions', 'wb') as outp:  # Overwrites any existing file.
      pickle.dump(train_captions, outp, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Create training and validation sets

# %%
# Create vector with image and captions
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)
slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

# Train set
img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

# Validation set
img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

# %% [markdown]
# ## Create Dataset and Batches

# %%
# Settings some parameters
BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
num_steps = len(img_name_train) // BATCH_SIZE

# Shape of the vector extracted from InceptionV3 is (64, 2048)
features_shape = 2048
attention_features_shape = 64

# %%
# Load preprocessed images
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
# Create final dataset
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int64]),
          num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## Model

# %%
# Attention class definition

class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, features, hidden):
    # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

    # hidden shape == (batch_size, hidden_size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
    hidden_with_time_axis = tf.expand_dims(hidden, 1)

    # attention_hidden_layer shape == (batch_size, 64, units)
    attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                         self.W2(hidden_with_time_axis)))

    # score shape == (batch_size, 64, 1)
    # This gives you an unnormalized score for each image feature.
    score = self.V(attention_hidden_layer)

    # attention_weights shape == (batch_size, 64, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
# CNN Encoder definition

class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.embedding_dim = embedding_dim
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x
    
    def get_config(self):
      return {"embedding_dim": self.embedding_dim}

    @classmethod
    def from_config(cls, config):
      return cls(**config)

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units

    self.embedding_dim = embedding_dim
    self.vocab_size = vocab_size
    self.embedding = tf.keras.layers.Embedding(self.vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(self.vocab_size)

    self.attention = BahdanauAttention(self.units)

  def call(self, x, features, hidden):
    # defining attention as a separate model
    context_vector, attention_weights = self.attention(features, hidden)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # shape == (batch_size, max_length, hidden_size)
    x = self.fc1(output)

    # x shape == (batch_size * max_length, hidden_size)
    x = tf.reshape(x, (-1, x.shape[2]))

    # output shape == (batch_size * max_length, vocab)
    x = self.fc2(x)

    return x, state, attention_weights

  def _reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

  def get_config(self):
    return {"embedding_dim": self.embedding_dim,"units": self.units,"embedding_dim": self.embedding_dim}

  @classmethod
  def from_config(cls, config):
      return cls(**config)

  @tf.function
  def reset_state(self, batch_size):
      """ tf.function-deocrated version of _reset_state """
      return self._reset_state(batch_size)

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, tokenizer.vocabulary_size())

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoint

# %%
checkpoint_path = "./checkpoints/3_captioning_train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %% [markdown]
# ## Train

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0

  # initializing the hidden state for each batch
  # because the captions are not related from image to image
  hidden = decoder.reset_state(batch_size=target.shape[0])

  dec_input = tf.expand_dims([word_to_index('<start>')] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)
      for i in range(1, target.shape[1]):
          # passing the features through the decoder
          predictions, hidden, _ = decoder(dec_input, features, hidden)

          loss += loss_function(target[:, i], predictions)

          # using teacher forcing
          dec_input = tf.expand_dims(target[:, i], 1)

  total_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, trainable_variables)

  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, total_loss

# %%
EPOCHS = 10
max_length = 5

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            average_batch_loss = batch_loss.numpy()/int(target.shape[1])
            print(f'Epoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
      ckpt_manager.save()

    print(f'Epoch {epoch+1} Loss {total_loss/num_steps:.6f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 1.1566
# Epoch 1 Batch 100 Loss 1.1497
# Epoch 1 Batch 200 Loss 1.2002
# Epoch 1 Batch 300 Loss 1.1829
# Epoch 1 Batch 400 Loss 1.2898
# Epoch 1 Batch 500 Loss 1.1032
# Epoch 1 Batch 600 Loss 1.2633
# Epoch 1 Batch 700 Loss 1.1682
# Epoch 1 Batch 800 Loss 1.2040
# Epoch 1 Batch 900 Loss 1.2051
# Epoch 1 Batch 1000 Loss 1.2861
# Epoch 1 Batch 1100 Loss 1.2087
# Epoch 1 Batch 1200 Loss 1.2037
# Epoch 1 Batch 1300 Loss 1.0760
# Epoch 1 Batch 1400 Loss 1.0243
# Epoch 1 Batch 1500 Loss 1.1520
# Epoch 1 Batch 1600 Loss 1.1334
# Epoch 1 Batch 1700 Loss 1.2401
# Epoch 1 Batch 1800 Loss 1.1663
# Epoch 1 Batch 1900 Loss 1.1650
# Epoch 1 Batch 2000 Loss 1.3099
# Epoch 1 Batch 2100 Loss 1.1701
# Epoch 1 Batch 2200 Loss 1.1967
# Epoch 1 Batch 2300 Loss 1.1441
# Epoch 1 Batch 2400 Loss 1.1864
# Epoch 1 Batch 2500 Loss 1.1590
# Epoch 1 Batch 2600 Loss 1.2674
# Epoch 1 Batch 2700 Loss 1.2426
# Epoch 1 Batch 2800 Loss 1.1406
# Epoch 1 Batch 2900 Loss 1.1035
# Epoch 1 Batch 3000 Loss 1.1980
# Epoch 1 Batch 3100 Loss 1.2456
# Epoch 1 Loss 1.192092
# Time taken for 1 epoch 110.67 sec
#
# Epoch 2 Batch 0 Loss 1.0846
# Epoch 2 Batch 100 Loss 1.1166
# Epoch 2 Batch 200 Loss 1.3020
# Epoch 2 Batch 300 Loss 1.1413
# Epoch 2 Batch 400 Loss 1.1550
# Epoch 2 Batch 500 Loss 1.2437
# Epoch 2 Batch 600 Loss 1.2062
# Epoch 2 Batch 700 Loss 1.1668
# Epoch 2 Batch 800 Loss 1.1116
# Epoch 2 Batch 900 Loss 1.0899
# Epoch 2 Batch 1000 Loss 1.4149
# Epoch 2 Batch 1100 Loss 1.2673
# Epoch 2 Batch 1200 Loss 1.2997
# Epoch 2 Batch 1300 Loss 1.1992
# Epoch 2 Batch 1400 Loss 1.1136
# Epoch 2 Batch 1500 Loss 1.2077
# Epoch 2 Batch 1600 Loss 1.1757
# Epoch 2 Batch 1700 Loss 1.1957
# Epoch 2 Batch 1800 Loss 1.2404
# Epoch 2 Batch 1900 Loss 1.2199
# Epoch 2 Batch 2000 Loss 1.3153
# Epoch 2 Batch 2100 Loss 1.2042
# Epoch 2 Batch 2200 Loss 1.2401
# Epoch 2 Batch 2300 Loss 1.3547
# Epoch 2 Batch 2400 Loss 1.1075
# Epoch 2 Batch 2500 Loss 1.1865
# Epoch 2 Batch 2600 Loss 1.1780
# Epoch 2 Batch 2700 Loss 1.2087
# Epoch 2 Batch 2800 Loss 1.1535
# Epoch 2 Batch 2900 Loss 1.1324
# Epoch 2 Batch 3000 Loss 1.0573
# Epoch 2 Batch 3100 Loss 1.1908
# Epoch 2 Loss 1.190252
# Time taken for 1 epoch 110.74 sec
#
# Epoch 3 Batch 0 Loss 1.1804
# Epoch 3 Batch 100 Loss 1.1564
# Epoch 3 Batch 200 Loss 1.1912
# Epoch 3 Batch 300 Loss 1.1199
# Epoch 3 Batch 400 Loss 1.2456
# Epoch 3 Batch 500 Loss 1.2505
# Epoch 3 Batch 600 Loss 1.2158
# Epoch 3 Batch 700 Loss 1.1544
# Epoch 3 Batch 800 Loss 1.1892
# Epoch 3 Batch 900 Loss 1.2258
# Epoch 3 Batch 1000 Loss 1.1724
# Epoch 3 Batch 1100 Loss 1.2203
# Epoch 3 Batch 1200 Loss 1.1598
# Epoch 3 Batch 1300 Loss 1.0757
# Epoch 3 Batch 1400 Loss 1.2067
# Epoch 3 Batch 1500 Loss 1.1141
# Epoch 3 Batch 1600 Loss 1.1540
# Epoch 3 Batch 1700 Loss 1.1748
# Epoch 3 Batch 1800 Loss 1.0706
# Epoch 3 Batch 1900 Loss 1.1318
# Epoch 3 Batch 2000 Loss 1.2205
# Epoch 3 Batch 2100 Loss 1.1542
# Epoch 3 Batch 2200 Loss 1.3343
# Epoch 3 Batch 2300 Loss 1.1131
# Epoch 3 Batch 2400 Loss 1.1674
# Epoch 3 Batch 2500 Loss 1.2580
# Epoch 3 Batch 2600 Loss 1.2193
# Epoch 3 Batch 2700 Loss 1.1977
# Epoch 3 Batch 2800 Loss 1.3084
# Epoch 3 Batch 2900 Loss 1.1968
# Epoch 3 Batch 3000 Loss 1.2363
# Epoch 3 Batch 3100 Loss 1.1079
# Epoch 3 Loss 1.187288
# Time taken for 1 epoch 110.18 sec
#
# Epoch 4 Batch 0 Loss 1.2415
# Epoch 4 Batch 100 Loss 1.2266
# Epoch 4 Batch 200 Loss 1.2768
# Epoch 4 Batch 300 Loss 1.2620
# Epoch 4 Batch 400 Loss 1.1046
# Epoch 4 Batch 500 Loss 1.1729
# Epoch 4 Batch 600 Loss 1.1323
# Epoch 4 Batch 700 Loss 1.0978
# Epoch 4 Batch 800 Loss 1.1436
# Epoch 4 Batch 900 Loss 1.1258
# Epoch 4 Batch 1000 Loss 1.1390
# Epoch 4 Batch 1100 Loss 1.2094
# Epoch 4 Batch 1200 Loss 1.1126
# Epoch 4 Batch 1300 Loss 1.0952
# Epoch 4 Batch 1400 Loss 1.1313
# Epoch 4 Batch 1500 Loss 1.1184
# Epoch 4 Batch 1600 Loss 1.1563
# Epoch 4 Batch 1700 Loss 1.1799
# Epoch 4 Batch 1800 Loss 1.1427
# Epoch 4 Batch 1900 Loss 1.2671
# Epoch 4 Batch 2000 Loss 1.2303
# Epoch 4 Batch 2100 Loss 1.2779
# Epoch 4 Batch 2200 Loss 1.1760
# Epoch 4 Batch 2300 Loss 1.1811
# Epoch 4 Batch 2400 Loss 1.2074
# Epoch 4 Batch 2500 Loss 1.2305
# Epoch 4 Batch 2600 Loss 1.2777
# Epoch 4 Batch 2700 Loss 1.3280
# Epoch 4 Batch 2800 Loss 1.1443
# Epoch 4 Batch 2900 Loss 1.2077
# Epoch 4 Batch 3000 Loss 1.2216
# Epoch 4 Batch 3100 Loss 1.2777
# Epoch 4 Loss 1.185214
# Time taken for 1 epoch 110.22 sec
#
# Epoch 5 Batch 0 Loss 1.2109
# Epoch 5 Batch 100 Loss 1.2318
# Epoch 5 Batch 200 Loss 1.0754
# Epoch 5 Batch 300 Loss 1.1994
# Epoch 5 Batch 400 Loss 1.2309
# Epoch 5 Batch 500 Loss 1.1158
# Epoch 5 Batch 600 Loss 1.0623
# Epoch 5 Batch 700 Loss 1.1163
# Epoch 5 Batch 800 Loss 1.1676
# Epoch 5 Batch 900 Loss 1.2595
# Epoch 5 Batch 1000 Loss 1.2859
# Epoch 5 Batch 1100 Loss 1.2023
# Epoch 5 Batch 1200 Loss 1.2127
# Epoch 5 Batch 1300 Loss 1.1784
# Epoch 5 Batch 1400 Loss 1.0769
# Epoch 5 Batch 1500 Loss 1.2735
# Epoch 5 Batch 1600 Loss 1.0485
# Epoch 5 Batch 1700 Loss 1.1708
# Epoch 5 Batch 1800 Loss 1.1821
# Epoch 5 Batch 1900 Loss 1.1941
# Epoch 5 Batch 2000 Loss 1.1348
# Epoch 5 Batch 2100 Loss 1.1256
# Epoch 5 Batch 2200 Loss 1.1521
# Epoch 5 Batch 2300 Loss 1.2053
# Epoch 5 Batch 2400 Loss 1.1241
# Epoch 5 Batch 2500 Loss 1.2804
# Epoch 5 Batch 2600 Loss 1.2287
# Epoch 5 Batch 2700 Loss 1.2278
# Epoch 5 Batch 2800 Loss 1.0634
# Epoch 5 Batch 2900 Loss 1.1146
# Epoch 5 Batch 3000 Loss 1.2128
# Epoch 5 Batch 3100 Loss 1.2271
# Epoch 5 Loss 1.181983
# Time taken for 1 epoch 110.23 sec
#
# Epoch 6 Batch 0 Loss 1.0552
# Epoch 6 Batch 100 Loss 1.1400
# Epoch 6 Batch 200 Loss 1.1252
# Epoch 6 Batch 300 Loss 1.2038
# Epoch 6 Batch 400 Loss 1.1844
# Epoch 6 Batch 500 Loss 1.1675
# Epoch 6 Batch 600 Loss 1.2861
# Epoch 6 Batch 700 Loss 1.2120
# Epoch 6 Batch 800 Loss 1.0968
# Epoch 6 Batch 900 Loss 1.2666
# Epoch 6 Batch 1000 Loss 1.1984
# Epoch 6 Batch 1100 Loss 1.2007
# Epoch 6 Batch 1200 Loss 1.1255
# Epoch 6 Batch 1300 Loss 1.1656
# Epoch 6 Batch 1400 Loss 1.0554
# Epoch 6 Batch 1500 Loss 1.0901
# Epoch 6 Batch 1600 Loss 1.1424
# Epoch 6 Batch 1700 Loss 1.1231
# Epoch 6 Batch 1800 Loss 1.0727
# Epoch 6 Batch 1900 Loss 1.1231
# Epoch 6 Batch 2000 Loss 1.1948
# Epoch 6 Batch 2100 Loss 1.1814
# Epoch 6 Batch 2200 Loss 1.1379
# Epoch 6 Batch 2300 Loss 1.2400
# Epoch 6 Batch 2400 Loss 1.1279
# Epoch 6 Batch 2500 Loss 1.1795
# Epoch 6 Batch 2600 Loss 1.1580
# Epoch 6 Batch 2700 Loss 1.1489
# Epoch 6 Batch 2800 Loss 1.1092
# Epoch 6 Batch 2900 Loss 1.1993
# Epoch 6 Batch 3000 Loss 1.1921
# Epoch 6 Batch 3100 Loss 1.1689
# Epoch 6 Loss 1.178957
# Time taken for 1 epoch 110.19 sec
#
# Epoch 7 Batch 0 Loss 1.2521
# Epoch 7 Batch 100 Loss 1.1978
# Epoch 7 Batch 200 Loss 1.1118
# Epoch 7 Batch 300 Loss 1.1701
# Epoch 7 Batch 400 Loss 1.1959
# Epoch 7 Batch 500 Loss 1.1955
# Epoch 7 Batch 600 Loss 1.2638
# Epoch 7 Batch 700 Loss 1.1380
# Epoch 7 Batch 800 Loss 1.2423
# Epoch 7 Batch 900 Loss 1.2835
# Epoch 7 Batch 1000 Loss 1.1815
# Epoch 7 Batch 1100 Loss 1.1584
# Epoch 7 Batch 1200 Loss 1.0719
# Epoch 7 Batch 1300 Loss 1.0414
# Epoch 7 Batch 1400 Loss 1.0862
# Epoch 7 Batch 1500 Loss 1.2015
# Epoch 7 Batch 1600 Loss 1.1646
# Epoch 7 Batch 1700 Loss 1.0761
# Epoch 7 Batch 1800 Loss 1.0980
# Epoch 7 Batch 1900 Loss 1.1496
# Epoch 7 Batch 2000 Loss 1.1412
# Epoch 7 Batch 2100 Loss 1.0788
# Epoch 7 Batch 2200 Loss 1.1894
# Epoch 7 Batch 2300 Loss 1.2103
# Epoch 7 Batch 2400 Loss 1.1518
# Epoch 7 Batch 2500 Loss 1.0834
# Epoch 7 Batch 2600 Loss 1.1614
# Epoch 7 Batch 2700 Loss 1.1604
# Epoch 7 Batch 2800 Loss 1.2388
# Epoch 7 Batch 2900 Loss 1.2015
# Epoch 7 Batch 3000 Loss 1.1587
# Epoch 7 Batch 3100 Loss 1.0330
# Epoch 7 Loss 1.179446
# Time taken for 1 epoch 109.57 sec
#
# Epoch 8 Batch 0 Loss 1.1993
# Epoch 8 Batch 100 Loss 1.1727
# Epoch 8 Batch 200 Loss 1.1266
# Epoch 8 Batch 300 Loss 1.1875
# Epoch 8 Batch 400 Loss 1.1082
# Epoch 8 Batch 500 Loss 1.1073
# Epoch 8 Batch 600 Loss 1.1427
# Epoch 8 Batch 700 Loss 1.0652
# Epoch 8 Batch 800 Loss 1.0790
# Epoch 8 Batch 900 Loss 1.2001
# Epoch 8 Batch 1000 Loss 1.1324
# Epoch 8 Batch 1100 Loss 1.0228
# Epoch 8 Batch 1200 Loss 1.3423
# Epoch 8 Batch 1300 Loss 1.1920
# Epoch 8 Batch 1400 Loss 1.0984
# Epoch 8 Batch 1500 Loss 1.1277
# Epoch 8 Batch 1600 Loss 1.1014
# Epoch 8 Batch 1700 Loss 1.2771
# Epoch 8 Batch 1800 Loss 1.0730
# Epoch 8 Batch 1900 Loss 1.2084
# Epoch 8 Batch 2000 Loss 1.1357
# Epoch 8 Batch 2100 Loss 1.2565
# Epoch 8 Batch 2200 Loss 1.0968
# Epoch 8 Batch 2300 Loss 1.2106
# Epoch 8 Batch 2400 Loss 1.1276
# Epoch 8 Batch 2500 Loss 1.0951
# Epoch 8 Batch 2600 Loss 1.1580
# Epoch 8 Batch 2700 Loss 1.1399
# Epoch 8 Batch 2800 Loss 1.1446
# Epoch 8 Batch 2900 Loss 1.2062
# Epoch 8 Batch 3000 Loss 1.1732
# Epoch 8 Batch 3100 Loss 1.0954
# Epoch 8 Loss 1.176004
# Time taken for 1 epoch 110.47 sec
#
# Epoch 9 Batch 0 Loss 1.2443
# Epoch 9 Batch 100 Loss 1.1960
# Epoch 9 Batch 200 Loss 1.1330
# Epoch 9 Batch 300 Loss 1.1519
# Epoch 9 Batch 400 Loss 1.2003
# Epoch 9 Batch 500 Loss 1.1799
# Epoch 9 Batch 600 Loss 1.2939
# Epoch 9 Batch 700 Loss 1.1798
# Epoch 9 Batch 800 Loss 1.0854
# Epoch 9 Batch 900 Loss 1.2505
# Epoch 9 Batch 1000 Loss 1.1922
# Epoch 9 Batch 1100 Loss 1.2167
# Epoch 9 Batch 1200 Loss 1.1856
# Epoch 9 Batch 1300 Loss 1.1079
# Epoch 9 Batch 1400 Loss 1.1116
# Epoch 9 Batch 1500 Loss 1.2073
# Epoch 9 Batch 1600 Loss 1.2017
# Epoch 9 Batch 1700 Loss 1.2552
# Epoch 9 Batch 1800 Loss 1.3057
# Epoch 9 Batch 1900 Loss 1.2056
# Epoch 9 Batch 2000 Loss 1.2577
# Epoch 9 Batch 2100 Loss 1.1880
# Epoch 9 Batch 2200 Loss 1.1950
# Epoch 9 Batch 2300 Loss 1.1606
# Epoch 9 Batch 2400 Loss 1.1168
# Epoch 9 Batch 2500 Loss 1.2050
# Epoch 9 Batch 2600 Loss 1.2680
# Epoch 9 Batch 2700 Loss 1.1484
# Epoch 9 Batch 2800 Loss 1.1250
# Epoch 9 Batch 2900 Loss 1.1598
# Epoch 9 Batch 3000 Loss 1.1345
# Epoch 9 Batch 3100 Loss 1.1946
# Epoch 9 Loss 1.171907
# Time taken for 1 epoch 108.44 sec
#
# Epoch 10 Batch 0 Loss 1.1901
# Epoch 10 Batch 100 Loss 0.9669
# Epoch 10 Batch 200 Loss 1.2118
# Epoch 10 Batch 300 Loss 1.1378
# Epoch 10 Batch 400 Loss 1.1260
# Epoch 10 Batch 500 Loss 1.0483
# Epoch 10 Batch 600 Loss 1.2810
# Epoch 10 Batch 700 Loss 1.1082
# Epoch 10 Batch 800 Loss 1.1950
# Epoch 10 Batch 900 Loss 1.1703
# Epoch 10 Batch 1000 Loss 1.3468
# Epoch 10 Batch 1100 Loss 1.0957
# Epoch 10 Batch 1200 Loss 1.0828
# Epoch 10 Batch 1300 Loss 1.0918
# Epoch 10 Batch 1400 Loss 1.2021
# Epoch 10 Batch 1500 Loss 1.2083
# Epoch 10 Batch 1600 Loss 1.2506
# Epoch 10 Batch 1700 Loss 1.3234
# Epoch 10 Batch 1800 Loss 1.1562
# Epoch 10 Batch 1900 Loss 1.2334
# Epoch 10 Batch 2000 Loss 1.1165
# Epoch 10 Batch 2100 Loss 1.1889
# Epoch 10 Batch 2200 Loss 1.1547
# Epoch 10 Batch 2300 Loss 1.1908
# Epoch 10 Batch 2400 Loss 1.0645
# Epoch 10 Batch 2500 Loss 1.1750
# Epoch 10 Batch 2600 Loss 1.2602
# Epoch 10 Batch 2700 Loss 1.2935
# Epoch 10 Batch 2800 Loss 1.1568
# Epoch 10 Batch 2900 Loss 1.1914
# Epoch 10 Batch 3000 Loss 1.0833
# Epoch 10 Batch 3100 Loss 1.1486
# Epoch 10 Loss 1.170551
# Time taken for 1 epoch 110.90 sec

# %% [markdown]
# ## Graphs

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# ## Evaluate

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0],
                                                 -1,
                                                 img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([word_to_index('<start>')], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input,
                                                         features,
                                                         hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        predicted_word = tf.compat.as_text(index_to_word(predicted_id).numpy())
        result.append(predicted_word)

        if predicted_word == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for i in range(len_result):
        temp_att = np.resize(attention_plot[i], (8, 8))
        grid_size = max(int(np.ceil(len_result/2)), 2)
        ax = fig.add_subplot(grid_size, grid_size, i+1)
        ax.set_title(result[i])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy())
                         for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)
print('Real Caption:', real_caption)
print('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a penguin with a hat sitting in
# Prediction Caption: ramp. situated the summer toast

# %% [markdown]
# ## Save Models

# %%
import datetime
import pandas as pd

date:datetime = datetime.datetime.now().strftime("%m.%d.%Y_%H:%M:%S")
model_dir:str = f"models/cap_encoder_{date}"
encoder.save(model_dir)
date:datetime = datetime.datetime.now().strftime("%m.%d.%Y_%H:%M:%S")
model_dir:str = f"models/cap_decoder_{date}"
decoder.save(model_dir)
# Out:
# INFO:tensorflow:Assets written to: models/cap_encoder_10.20.2022_23:15:55/assets
# INFO:tensorflow:Assets written to: models/cap_encoder_10.20.2022_23:15:55/assets
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/cap_decoder_10.20.2022_23:15:56/assets
# INFO:tensorflow:Assets written to: models/cap_decoder_10.20.2022_23:15:56/assets

# %% [markdown]
# ## Try on unkown images

# %%
# tounum_path = 'data/1_data_cat_thomas/val/photo/'
tounum_path = 'data/0_data_unseen/data/'
tounum_images = os.listdir(tounum_path)

for image_path in tounum_images[:10]:
    result, attention_plot = evaluate(tounum_path + image_path)
    print('Prediction Caption:', ' '.join(result))
    plot_attention(tounum_path + image_path, result, attention_plot)
    # opening the image
    Image.open(tounum_path + image_path)
# Out:
# Prediction Caption: bird stuffed room. on a
# Prediction Caption: two open walking and vests
# Prediction Caption: a man with laying [UNK]
# Prediction Caption: a group of image [UNK]
